# %% [markdown]
# # <h1 align="center"> OpenCV <h1>

# %% [markdown]
# ### Task 1: Install Opencv

# %% [markdown]
# in anaconda prompt --> pip install opencv-python

# %% [markdown]
# ### Task 2: Read Image using Opencv

# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.image as mpimg
from skimage import color
from skimage import io
from PIL import Image 
import PIL 
import os

# %%
img=cv.imread("F:/Nada/swar/wallpaper/14.JPG")

# %%
plt.imshow(img)

# %% [markdown]
# ### Task 3: Read Video using Opencv

# %%
video = cv.VideoCapture("D:/fcis/Ai Course/What is Python_ Why Python is So Popular_.MP4")

# %%
#video = cv.VideoCapture('qoumia.mp4')
# Check if camera opened successfully
if (video.isOpened()== False): 
    print("Error opening video stream or file")

# Read until video is completed
while(video.isOpened()):
    # Capture frame-by-frame
    ret, frame = video.read()
    if ret == True:
        # Display the resulting frame
        cv.imshow('Frame',frame)

        # Press Q on keyboard to  exit
        if cv.waitKey(25) & 0xFF == ord('q'):
            break

  # Break the loop
    else: 
        break

# When everything done, release the video capture object
video.release()

# Closes all the frames
cv.destroyAllWindows()

# %% [markdown]
# ### Task 4: Resize Image

# %%
cv.resize(img,(500,500))
# Out:
# array([[[65, 35, 34],
#         [64, 34, 33],
#         [65, 35, 34],
#         ...,
#         [66, 36, 35],
#         [65, 35, 34],
#         [63, 33, 32]],
#
#        [[65, 35, 34],
#         [64, 34, 33],
#         [65, 35, 34],
#         ...,
#         [66, 35, 35],
#         [65, 35, 34],
#         [64, 34, 33]],
#
#        [[64, 34, 33],
#         [64, 34, 33],
#         [64, 34, 33],
#         ...,
#         [65, 35, 34],
#         [64, 34, 33],
#         [63, 33, 32]],
#
#        ...,
#
#        [[45, 24, 33],
#         [45, 24, 33],
#         [48, 25, 33],
#         ...,
#         [46, 24, 29],
#         [47, 25, 30],
#         [47, 25, 30]],
#
#        [[45, 23, 33],
#         [45, 24, 33],
#         [47, 24, 32],
#         ...,
#         [47, 25, 30],
#         [46, 24, 29],
#         [48, 26, 31]],
#
#        [[47, 26, 35],
#         [45, 24, 33],
#         [46, 23, 31],
#         ...,
#         [47, 25, 30],
#         [48, 26, 31],
#         [46, 24, 29]]], dtype=uint8)

# %% [markdown]
# ### Task 5: Convert RGB to Gray Scale

# %%
#imgGray = color.rgb2gray(img)
imgGray=cv.cvtColor(img, cv.COLOR_BGR2GRAY)

# %%
plt.imshow(imgGray)

# %% [markdown]
# ### Task 6: Save New Image

# %%
#SavedImage=Image.open("F:/Nada/swar/wallpaper/14.JPG")
#SavedImage=SavedImage.save("night.JPG") 
cv.imwrite("D:/fcis/Ai Course/x.JPG",imgGray)
# Out:
# True

# %% [markdown]
# ![x.JPG](attachment:x.JPG)

# %% [markdown]
# ### Task 7: Read Live Camera

# %%
video = cv.VideoCapture(0)
# Check if camera opened successfully
if (video.isOpened()== False): 
    print("Error opening video stream or file")

# Read until video is completed
while(video.isOpened()):
    # Capture frame-by-frame
    ret, frame = video.read()
    if ret == True:
        # Display the resulting frame
        cv.imshow('Frame',frame)

        # Press Q on keyboard to  exit
        if cv.waitKey(25) & 0xFF == ord('q'):
            break

  # Break the loop
    else: 
        break

# When everything done, release the video capture object
video.release()

# Closes all the frames
cv.destroyAllWindows()

# %% [markdown]
# ### Task 9:

# %% [markdown]
# ### Task 10:  visualize Image

# %% [markdown]
# ### Task 11: Find Contours in image

# %%
thresh = 100
#get threshold image
ret,thresh_img = cv.threshold(imgGray, thresh, 255, cv.THRESH_BINARY)
#find contours
contours, hierarchy = cv.findContours(thresh_img, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)

#create an empty image for contours
img_contours = np.zeros(img.shape)
# draw the contours on the empty image
cv.drawContours(img_contours, contours, -1, (0,255,0), 3)
#save image
cv.imwrite('D:/fcis/Ai Course/contours.png',img_contours)
# Out:
# True

# %% [markdown]
# ![contours.png](attachment:contours.png)

# %% [markdown]
# ### Task 12: Detect Edges

# %%
# perform the canny edge detector to detect image edges
edges = cv.Canny(imgGray, threshold1=30, threshold2=100)

# %%
plt.imshow(edges)

# %%
kernel = np.ones((5,5),np.float32)/25
dst = cv.filter2D(img,-1,kernel)
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(dst),plt.title('Averaging')
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ### Task 13: Apply different filters on image

# %% [markdown]
# ### Task 16: Face detection

# %%
cascPath=os.path.dirname(cv.__file__)+"/data/haarcascade_frontalface_default.xml"
faceCascade = cv.CascadeClassifier(cascPath)

# %%
video_capture = cv.VideoCapture(0)
while True:
    # Capture frame-by-frame
    ret, frames = video_capture.read()
    gray = cv.cvtColor(frames, cv.COLOR_BGR2GRAY)
    faces = faceCascade.detectMultiScale(
        gray,
        scaleFactor=1.1,
        minNeighbors=5,
        minSize=(30, 30),
        flags=cv.CASCADE_SCALE_IMAGE
    )
    # Draw a rectangle around the faces
    for (x, y, w, h) in faces:
        cv.rectangle(frames, (x, y), (x+w, y+h), (0, 255, 0), 2)
    # Display the resulting frame
    cv.imshow('Video', frames)
    if cv.waitKey(1) & 0xFF == ord('q'):
        break

# %%
video_capture.release()
cv.destroyAllWindows()
